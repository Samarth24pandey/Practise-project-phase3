# %% [markdown]
# # Project Description
# The dataset contains grades scored by students throughout their university tenure in various courses and their CGPA calculated based on their grades

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the data of the grades.

# %%
df = pd.read_csv("Grades.csv")

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 0       B-  ...     C-     C-     C-     C-     A-      A     C-      B
# 1       D+  ...     D+      D      C      D     A-     B-      C      C
# 2       A-  ...      B      B      A      C      A      A      A     A-
# 3        D  ...     D+      C     D+     C-     B-      B     C+     C+
# 4        A  ...     B-     B+     B+     B-     A-      A     A-     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 0       A-  2.205
# 1        B  2.008
# 2        A  3.608
# 3       C+  1.906
# 4        A  3.448
# ..     ...    ...
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [571 rows x 43 columns]

# %% [markdown]
# This dataset contains of 571 rows and 43 coloumns with the description of the grades of students for different years.

# %% [markdown]
# # Variables in Dataset:

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (571, 43)

# %%
print(f"The rows and columns in the dataset:{df.shape}")
print(f"The column headers in the dataset:{df.columns}")
# Out:
# The rows and columns in the dataset:(571, 43)
# The column headers in the dataset:Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %% [markdown]
# # Data Exploration

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
#  19  CS-214     565 non-null    object
#  20  EE-217     565 non-null    object
#  21  CS-212     565 non-null    object
#  22  CS-215     565 non-null    object
#  23  MT-331     562 non-null    object
#  24  EF-303     561 non-null    object
#  25  HS-304     561 non-null    object
#  26  CS-301     561 non-null    object
#  27  CS-302     561 non-null    object
#  28  TC-383     561 non-null    object
#  29  MT-442     561 non-null    object
#  30  EL-332     562 non-null    object
#  31  CS-318     562 non-null    object
#  32  CS-306     562 non-null    object
#  33  CS-312     561 non-null    object
#  34  CS-317     559 non-null    object
#  35  CS-403     559 non-null    object
#  36  CS-421     559 non-null    object
#  37  CS-406     486 non-null    object
#  38  CS-414     558 non-null    object
#  39  CS-419     558 non-null    object
#  40  CS-423     557 non-null    object
#  41  CS-412     492 non-null    object
#  42  CGPA       571 non-null    float64
# dtypes: float64(1), object(42)
# memory usage: 191.9+ KB

# %%
# Checking for the null values if any.

# %%
df.isnull()
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0       False   False   False   False      False   False   False   False
# 1       False   False   False   False      False   False   False   False
# 2       False   False   False   False      False   False   False   False
# 3       False   False   False   False      False   False   False   False
# 4       False   False   False   False      False   False   False   False
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566     False   False   False   False      False   False   False   False
# 567     False   False   False   False      False   False   False   False
# 568     False   False   False   False      False   False   False   False
# 569     False   False   False   False      False   False   False   False
# 570     False   False   False   False      False   False   False   False
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 0     False   False  ...   False   False   False   False   False   False
# 1     False   False  ...   False   False   False   False   False   False
# 2     False   False  ...   False   False   False   False   False   False
# 3     False   False  ...   False   False   False   False   False   False
# 4     False   False  ...   False   False   False   False   False   False
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 566   False   False  ...   False   False   False   False   False   False
# 567   False   False  ...   False   False   False   False   False   False
# 568   False   False  ...   False   False   False   False   False   False
# 569   False   False  ...   False   False   False   False   False   False
# 570   False   False  ...   False   False   False   False   False   False
#
#      CS-419  CS-423  CS-412   CGPA
# 0     False   False   False  False
# 1     False   False   False  False
# 2     False   False   False  False
# 3     False   False   False  False
# 4     False   False   False  False
# ..      ...     ...     ...    ...
# 566   False   False   False  False
# 567   False   False   False  False
# 568   False   False   False  False
# 569   False   False   False  False
# 570   False   False   False  False
#
# [571 rows x 43 columns]

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 425

# %% [markdown]
# # Cleaning the data

# %%
# To check if there is any missing value

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.replace(np.nan,0,inplace = True)
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
# 5  ...      C     B-     C+     C+     A-     A-     B+     B-      B  3.026
# 6  ...     B-      C     B+     B-      A     A-     B+     B+      A  2.957
# 7  ...     D+     B+     B+      C      A     B+     A-     A-     A-  3.043
# 8  ...     B+      B     B-     C+      A     A-     B+     A-      A  3.358
# 9  ...     C+     B-     B+     B-      A      A     A-      B      A  3.247
#
# [10 rows x 43 columns]

# %%
# Our traget value is "CGPA" so we will drop some of the columns

# %%
input = df.drop(["CS-403","CS-421","CS-406","CS-412","CS-419","CS-423","CS-412","MT-442","Seat No.","CGPA"], axis=1)
target = df[["CGPA"]]

# %%
target.head()
# Out:
#     CGPA
# 0  2.205
# 1  2.008
# 2  3.608
# 3  1.906
# 4  3.448

# %%
pd.unique(df["PH-121"])
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
grades_enc ={'B-':2.7, 'A':4, 'D':1.0, 'A-':3.7, 'B+':3.4, 'B':3.0, 'C+':2.4, 'C':2.0, 'C-':1.7, 'D+':1.4, 'WU':0.0, 'A+':4,'F':0.0,'W':0,'I':0}

# %%
type(input)
# Out:
# pandas.core.frame.DataFrame

# %%
for item in input:
    input[item] = input[item].replace(grades_enc)
input.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ...  HS-304  CS-301  CS-302  TC-383  EL-332  CS-318  CS-306  \
# 0     1.7  ...     2.4     3.0     2.0     2.4     2.0     1.7     2.0
# 1     1.0  ...     1.7     3.7     1.4     1.7     2.0     3.7     1.0
# 2     3.7  ...     4.0     3.4     3.7     3.0     3.4     3.7     3.7
# 3     2.4  ...     2.7     1.0     2.7     1.4     1.4     3.4     1.7
# 4     3.7  ...     3.7     2.7     3.7     2.4     3.7     2.7     3.7
#
#    CS-312  CS-317  CS-414
# 0     1.7     1.7     4.0
# 1     1.4     1.0     2.7
# 2     3.0     3.0     4.0
# 3     1.4     2.0     3.0
# 4     2.7     3.4     4.0
#
# [5 rows x 34 columns]

# %%
# Concating inputs and targets for data insights.

# %%
df = pd.concat([input,target], axis=1)

# %% [markdown]
# # Data Visualization

# %%
df.hist(bins=30,figsize=(30,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Checking for correlations
plt.figure(figsize=(20,15))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.018389    2.628371    3.262697    2.878984    2.988091    3.329247
# std      0.971594    0.908402    0.932997    1.019208    0.954343    0.799826
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.400000    2.000000    2.700000    2.000000    2.400000    3.000000
# 50%      3.400000    2.700000    3.700000    3.000000    3.400000    3.700000
# 75%      3.700000    3.400000    4.000000    3.700000    3.700000    4.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-301  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.961996    2.969877    3.020140    2.698599  ...    2.850788
# std      0.869226    0.981676    0.839463    1.029323  ...    0.970483
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      2.400000    2.400000    2.400000    1.700000  ...    2.000000
# 50%      3.000000    3.400000    3.400000    2.700000  ...    3.000000
# 75%      3.700000    3.700000    3.700000    3.700000  ...    3.700000
# max      4.000000    4.000000    4.000000    4.000000  ...    4.000000
#
#            CS-302      TC-383      EL-332      CS-318      CS-306      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.050088    2.873730    2.863748    2.628371    2.892119    2.892294
# std      0.877124    1.017053    1.009585    1.035205    0.989909    1.095450
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.700000    2.000000    2.000000    2.000000    2.400000    2.000000
# 50%      3.400000    3.000000    3.000000    2.700000    3.000000    3.000000
# 75%      3.700000    3.700000    3.700000    3.400000    3.700000    4.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#            CS-317      CS-414        CGPA
# count  571.000000  571.000000  571.000000
# mean     2.651138    3.349737    2.954888
# std      0.952455    0.918549    0.620552
# min      0.000000    0.000000    0.800000
# 25%      2.000000    3.000000    2.538000
# 50%      2.700000    3.700000    3.029000
# 75%      3.400000    4.000000    3.451000
# max      4.000000    4.000000    3.985000
#
# [8 rows x 35 columns]

# %%
df.to_csv('cleaned_data.csv')

# %%
# Splitting file into different columns based on our model prediction requirement.

# %%
model1_columns = []
model2_columns = []
model3_columns = []
for item in [input]:
    for i in item:
        if i[3]=='1':
            model1_columns.append(i)
        elif i[3]=='2':
            model2_columns.append(i)
        else:
            model3_columns.append(i)
            
model2_columns = model1_columns + model2_columns
model3_columns = model2_columns + model3_columns

# %% [markdown]
# # Prepare the date for LInear Regression
#
# # Model1 : Predict final CGPA based on GP of first year.

# %%
labels = df['CGPA'].values
features = df[list(model1_columns)].values

# %%
#Splitting the data 

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(features,labels, test_size=0.30)

# %%
# Building the model 

from sklearn import linear_model

lr_1 = linear_model.LinearRegression()

lr_1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict 
y_train_predict = lr_1.predict(x_train)

y_test_predict = lr_1.predict(x_test)

# %%
input_lr = []
input_lr.append([4,3.0,0,0,0,1.0,4,2.0,0,4,4])
print(input_lr)
print(lr_1.predict(input_lr))
# Out:
# [[4, 3.0, 0, 0, 0, 1.0, 4, 2.0, 0, 4, 4]]
# [1.96115634]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Model evaluation for training set
mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))

# Model evaluation for testing set
mse_test = mean_squared_error(y_test,y_test_predict)
mae_test = mean_absolute_error(y_test,y_test_predict)
print("The model performance for test set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("----------------------")
test_score = lr_1.score(x_test,y_test)
print("The score of model for testing is ")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.22990972950649782
# MAE is 0.1789086302167881
# The model performance for test set
# RMSE is 0.24393394495308154
# MAE is 0.18894870532050262
# ----------------------
# The score of model for testing is
# Test score 0.85

# %%
# Now comparing the actual and predicted score

compare={"Actual": y_test, "Predict": y_test_predict}
pd.DataFrame(compare)
# Out:
#      Actual   Predict
# 0     2.528  3.101778
# 1     2.607  2.686604
# 2     2.288  2.396953
# 3     3.220  3.332311
# 4     2.947  2.886789
# ..      ...       ...
# 167   2.779  2.387895
# 168   3.252  2.777111
# 169   2.505  2.712791
# 170   3.925  3.750906
# 171   3.245  3.186939
#
# [172 rows x 2 columns]

# %%
# Visualizing the result 

idx= np.random.choice(x_test.shape[0])
print("Predicted CGPA :", y_test_predict[idx])
print("Actual CGPA :", y_test[idx])
# Out:
# Predicted CGPA : 2.18347382737684
# Actual CGPA : 2.212

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test,y_test_predict, color='blue')
plt.scatter(y_train,y_train_predict, color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %% [markdown]
# # Model 2 Predict CGPA for First Three Years.

# %%
labels =df['CGPA'].values
features = df[list(model2_columns)].values

# %%
#Splitting Data 
x_train,x_test,y_train,y_test = train_test_split(features, labels, test_size=0.30)

# %%
# Building the model 

lr_2 = linear_model.LinearRegression()

#Training the model
lr_2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction 

y_train_predict = lr_2.predict(x_train)

y_test_predict = lr_2.predict(x_test)

# %%
# MOdel evaluation for training set
mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The mdel performance for trainig set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))
print('           ')

# Model evaluatoin fro testing set
mse_test = mean_squared_error(y_test, y_test_predict)
mae_test = mean_absolute_error(y_test, y_test_predict)
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("-------------------")

test_score = lr_2.score(x_test, y_test)
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The mdel performance for trainig set
# RMSE is 0.1709993019622409
# MAE is 0.12333537086534978
#
# The model performance for testing set
# RMSE is 0.1894111251950091
# MAE is 0.12521369113011901
# -------------------
# The score of model for testing set
# Test score 0.91

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test,y_test_predict, color='blue')
plt.scatter(y_train, y_train_predict, color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %% [markdown]
# # Model3 : Predict final CGPA for all 4 Years

# %%
labels = df['CGPA'].values
features = df[list(model3_columns)].values

# %%
# Splitting data 
x_train,x_test,y_train,y_test = train_test_split(features, labels, test_size=0.30)

# %%
# Building the model

lr_3 = linear_model.LinearRegression()

lr_3.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Prediction

y_train_predict = lr_3.predict(x_train)

y_test_predict = lr_3.predict(x_test)

# %%
# Model evaluation for training set
mse_train = mean_squared_error(y_train,y_train_predict)
mae_train = mean_absolute_error(y_train,y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MSE is {}'.format(mae_train))
print("                ")

# Model evaluation for testing set
mse_test = mean_squared_error(y_test,y_test_predict)
mae_test = mean_absolute_error(y_test,y_test_predict)
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MSE is {}'.format(mae_test))

print("------------------------")
test_score = lr_3.score(x_test,y_test)
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.11673372936708074
# MSE is 0.07105673451367879
#
# The model performance for testing set
# RMSE is 0.18161138439348196
# MSE is 0.09512477845155871
# ------------------------
# The score of model for testing set
# Test score 0.93

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test,y_test_predict,color='blue')
plt.scatter(y_train,y_train_predict, color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %%
del input

# %%
model_1=[]
model_2=[]
model_3=[]
input_lr=[]
name = input(" Project name ")
model = int(input("Which model would you like to predict"))
if model == 1:
    for val in model1_columns:
        string = "enter your "+ val +"GPA :"
        GPA = input(string)
        if GPA in grades_enc.keys():
            model_1.append(grades_enc[GPA])
        else:
            model_1.append(0)
    input_lr.append(model_1)
    print(f"{name},your predictive CGPA According to Linear Regression is :{lr_1.predict(input_lr)}")
# Out:
#  Project name Grade Predict
# Which model would you like to predict1
# enter your PH-121GPA :A
# enter your HS-101GPA :A
# enter your CY-105GPA :B
# enter your HS-105/12GPA :C
# enter your MT-111GPA :D
# enter your CS-105GPA :F
# enter your CS-106GPA :A
# enter your EL-102GPA :A
# enter your EE-119GPA :B-
# enter your ME-107GPA :C
# enter your CS-107GPA :E
# Grade Predict,your predictive CGPA According to Linear Regression is :[2.42975928]
